# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/MiniProjectDatasets/Diabetes_prediction/diabetes.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.countplot(data=df,x="Outcome",label="Count")

# %%
#lets visualise the number of rows and columns in the data frame 
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
WD,ND=df["Outcome"].value_counts()
print("Patient Which are diabetic {}".format(WD))
print("Patient Which are not diabetic {}".format(ND))
# Out:
# Patient Which are diabetic 500
# Patient Which are not diabetic 268

# %%
df.hist(figsize=(14,14),grid=False,xlabelsize=10,ylabelsize=10,legend=True)
plt.show()

# %%
plt.style.use("dark_background")
df.plot(kind="density",subplots=True,layout=(3,3),figsize=(14,14),sharex=False)
plt.show()

# %%
df.plot(kind="box",subplots=True,layout=(3,3),sharex=False,sharey=False,figsize=(14,14))
plt.show()

# %%
plt.style.use("default")

# %%
corr=df.corr()

# %%
corr
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.129459  ...  0.544341  0.221898
# Glucose                      0.129459  1.000000  ...  0.263514  0.466581
# BloodPressure                0.141282  0.152590  ...  0.239528  0.065068
# SkinThickness               -0.081672  0.057328  ... -0.113970  0.074752
# Insulin                     -0.073535  0.331357  ... -0.042163  0.130548
# BMI                          0.017683  0.221071  ...  0.036242  0.292695
# DiabetesPedigreeFunction    -0.033523  0.137337  ...  0.033561  0.173844
# Age                          0.544341  0.263514  ...  1.000000  0.238356
# Outcome                      0.221898  0.466581  ...  0.238356  1.000000
#
# [9 rows x 9 columns]

# %%
plt.figure(figsize=(14,14))
sns.heatmap(corr,cmap='magma',fmt="%",annot=True,linewidths=.5)

# %%
sns.pairplot(df)
